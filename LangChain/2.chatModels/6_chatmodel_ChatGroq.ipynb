# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model = 'llama-3.3-70b-versatile')
result = llm.invoke("what is the capital of india")
print(result.content)
# Out:
# The capital of India is **New Delhi**.

# %%
print(result)
# Out:
# content='The capital of India is **New Delhi**.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 41, 'total_tokens': 52, 'completion_time': 0.021395355, 'completion_tokens_details': None, 'prompt_time': 0.001405828, 'prompt_tokens_details': None, 'queue_time': 0.161198152, 'total_time': 0.022801183}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f1854-f1d2-71b1-bc9b-eaec09232160-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 41, 'output_tokens': 11, 'total_tokens': 52}
